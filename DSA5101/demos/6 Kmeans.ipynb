# %% [markdown]
# # DSA5101 - Introduction to Big Data for Industry
#
#
# **Prepared by *Dr Li Xiaoli***

# %% [markdown]
# # Python Source Code for K-means Clusterings
#
# ## We will
# * Import library
# * Prepare data sets by randomly generating data
# * Perform K-means clustering

# %% [markdown]
# ## 1. Import some important libraries

# %%
import numpy as np
import matplotlib.pyplot as plt  # package for visualization
from sklearn.cluster import KMeans    # package of clustering 
from sklearn.datasets import make_blobs   # package of generating data

# %%
import warnings  #ignore the warning information
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Prepare data sets

# %%
# Matplotlib is a Python 2D plotting library which produces publication quality 
# figures in a variety of hardcopy formats and interactive environments across platforms. 
# help(plt.figure)

# %% [markdown]
# # We will call make_blobs function
# * Randomly generate 1500 points (each 2-D vectors) belonging to 3 clusters
# * Each clusters contain 500 points (total 500*3=1500)
# * Centers : int or array of shape [n_centers, n_features], optional (default=3): The number of centers to generate
#
#
# # Parameter of make_blobs function
# * n_samples : int, optional (default=100): The total number of points equally divided among clusters.
# * n_features : int, optional (default=2):The number of features for each sample
# * random_state : random_state is the seed used by the random number generator

# %%
plt.figure(figsize=(50, 50))  # width=50, height=50 in inches
n_samples = 1500  #generate 1500 examples, each is a 2D vector
random_state = 170   #seed is 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state) #call the function
#1500 examples belong to three clusters

# %%
# help (make_blobs)

# %%
print (X)
# Out:
# [[-5.19811282e+00  6.41869316e-01]
#  [-5.75229538e+00  4.18627111e-01]
#  [-1.08448984e+01 -7.55352273e+00]
#  ...
#  [ 1.36105255e+00 -9.07491863e-01]
#  [-3.54141108e-01  7.12241630e-01]
#  [ 1.88577252e+00  1.41185693e-03]]

# %%
X.shape
# Out:
# (1500, 2)

# %%
print (y)
# We have three Cluters: Cluster 0, Cluster 1 and Cluster 2
# Out:
# [1 1 0 ... 2 2 2]

# %%
y.shape
# Out:
# (1500,)

# %%
for i in range(X.shape[0]):
    print (i+1, X[i], y[i])
# Out:
# 1 [-5.19811282  0.64186932] 1
# 2 [-5.75229538  0.41862711] 1
# 3 [-10.84489837  -7.55352273] 0
# 4 [-4.57098483 -0.80101741] 1
# 5 [-3.51916215  0.0393449 ] 1
# 6 [1.60391611 0.76388041] 2
# 7 [-9.75157357 -5.2030262 ] 0
# 8 [-11.51023635  -4.16284321] 0
# 9 [-7.72675795 -5.86656563] 0
# 10 [2.67656739 3.29872756] 2
# 11 [ 4.77999645 -0.32443193] 2
# 12 [ 1.07779207 -0.24999668] 2
# 13 [-8.5554513 -5.035368 ] 0
# 14 [2.15986392 1.120153  ] 2
# 15 [-8.81718975 -4.57925634] 0
# 16 [-2.5381617  -1.41827333] 1
# 17 [2.8353662  1.77322805] 2
# 18 [ 1.12915533 -0.83707668] 2
# 19 [-8.8931498  -5.32749594] 0
# 20 [-7.03528546 -4.63489973] 0
# 21 [-9.29099545 -6.11001533] 0
# 22 [ 2.21953088 -0.14202964] 2
# 23 [-8.99293921 -4.79926944] 0
# 24 [-3.77333905 -0.05101139] 1
# 25 [-8.14569117 -7.00119495] 0
# 26 [-5.00011836  0.2332823 ] 1
# 27 [ 3.14599765 -0.93275846] 2
# 28 [-4.04728854 -0.28806791] 1
# 29 [ 1.70176102 -0.70159523] 2
# 30 [-8.82010859 -6.84538977] 0
# ...

# %% [markdown]
# ## 3. Perform KMeans Clustering
# #### Main Function: KMeans

# %%
# help (KMeans())

# %% [markdown]
# ## Help on KMeans in module sklearn.cluster.k_means_ object. Some key parameters:
#
# ### n_clusters : int, optional, default: 8
# >The number of clusters to form, as well as the number of
# centroids to generate.
#
# ### max_iter : int, default: 300
# >Maximum number of iterations of the k-means algorithm for a single run.
#
# ### n_init : int, default: 10
# >Number of time the k-means algorithm will be run with different centroid seeds. The final results will be the **best output** of n_init consecutive runs in terms of inertia.
# > Guess: evaluate how much distance do the clusters move, i.e. if the clusters travelled small distances than it is highly likely that we are closest to best solution.
#
# ### random_state : integer or numpy.RandomState, optional
# >The generator used to initialize the centers. If an integer is
# given, it fixes the seed. Defaults to the global numpy random
# number generator.
#
# ### tol : float, default=1e-4
# >  Relative tolerance with regards to  Euclidean/Frobenius norm of the difference
# in the cluster centers of two consecutive iterations to declare
# convergence.
#
# ## Attribute of the Kmeans clustering results
# ### inertia_ : float
# > Sum of squared distances of samples to their closest cluster center.

# %% [markdown]
# ## Below, we will demo K-means using 4 different scenarios, i.e. 3.1-3.4

# %% [markdown]
# ## 3.1 Figure 1.1: Incorrect number of clusters (wrong K value): data X has three groups but we cluster it into two groups (K=2)

# %% [markdown]
# ### Use our generated data X to perform KMeans clustering
# ### Parameters
# * 2 clusters (k=2), which is inconsistent with our generated 3 clusters
# * random generated seeds

# %%
random_state
# Out:
# 170

# %%
# Note our generated data has 3 clusters/groups, but we group them into 2 clusters
y_pred_1 = KMeans(n_clusters=2, random_state=random_state).fit_predict(X)
# random_state=random_state: The generator used to initialize the centers. 
# random_state = 170
# y_pred_1 already stores labels
#KMeans will automatically predict the cluster of all the input data during the training, 
#because doing so is integral to the algorithm. It keeps them around for efficiency, 
#because predicting the labels for the original dataset is very common. 
#Thus, fit_predict adds very little: it calls fit, then returns . labels_

plt.scatter(X[:, 0], X[:, 1], c=y_pred_1)   # All rows and two columns (we draw 1500 2D data)
# y_pred_1: contain predicted two clusters: 
# c: color, meaning that we will show the data according to the predicted clusters, 
# each of the two generated clusters used different colors 
# X[:, 0], X[:, 1]: all of the data positions.

plt.title("Incorrect Number of Blobs")
# Out:
# Text(0.5, 1.0, 'Incorrect Number of Blobs')

# %% [markdown]
# ### Note yellow color cluster has eaten up a bit another cluster

# %%
# Store the clustering reseults
y_pred_1
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
y_pred_1.shape
# Out:
# (1500,)

# %% [markdown]
# ## Draw the cluster centers in our figure

# %%
############################
# Print Cluster Centers    #
############################
y_pred_1_center = KMeans(n_clusters=2, random_state=random_state).fit(X)

#As we use fit (X), we will need to get labels as follows
label=y_pred_1_center.labels_  #We would like to get label. Note here 
centroids = y_pred_1_center.cluster_centers_

u_labels = np.unique(label)
 
for i in u_labels:
    plt.scatter(X[label == i , 0] , X[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'k')
plt.legend()
plt.title("Incorrect Number of Blobs with Centers")
plt.show()

# %% [markdown]
# Note the center position for blue cluster!

# %%
y_pred_1
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %% [markdown]
# ## 3.1 Figure 1.2: Correct number of clusters (corrent K value): data X has three groups and we also cluster it into three groups (K=3)

# %%
# Note our generated data has 3 clusters, now we also group them into 3 clusters
y_pred_1dot5 = KMeans(n_clusters=3, random_state=random_state).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=y_pred_1dot5)   # All rows and two columns (we draw 1500 2D data)
plt.title("Correct Number of Blobs")
# Out:
# Text(0.5, 1.0, 'Correct Number of Blobs')

# %% [markdown]
# ### In general, K-means works well for Globular shape, even for boundary examples
# ### We are getting perfect clustering results

# %%
############################
# Print Cluster Centers    #
############################
y_pred_1dot5 = KMeans(n_clusters=3, random_state=random_state).fit(X)
label=y_pred_1dot5.labels_
centroids = y_pred_1dot5.cluster_centers_

u_labels = np.unique(label)
 
for i in u_labels:
    plt.scatter(X[label == i , 0] , X[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'k')
plt.legend()
plt.title("Correct Number of Blobs with Centers")
plt.show()

# %% [markdown]
# ## Our centers looks great!

# %%
# help(plt.scatter)

# %% [markdown]
# # Can we automatically decide the important paraemter k, i.e., n_clusters?

# %%
SSE = []
for i in range(1, 15):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    #'k-means++' : selects initial cluster centers for k-mean clustering in a smart way to speed up convergence.
    # Number of time the k-means algorithm will be run with different centroid seeds. 
    # The final results will be the best output of n_init consecutive runs in terms of inertia.
    kmeans.fit(X)
    SSE.append(kmeans.inertia_)
    # Inertia =SSE, measures how well a dataset was clustered by K-Means. It is calculated by measuring the distance 
    # between each data point and its centroid, squaring this distance, and summing these squares.
plt.plot(range(1, 15), SSE)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.xlim([0, 15])
plt.show()

# %% [markdown]
# ## It is amazing that we can automatically and accurately decide the number of clusters 3 using Elbow method!

# %% [markdown]
# However, it may not always work for other data sets or scenarios

# %%
#? kmeans

# %% [markdown]
# ## 3.2 Figure 2: Anisotropicly distributed data

# %%
# Perform transformation and then clustering (with K=3)

transformation = [[ 0.60834549, -0.63667341], [-0.40887718, 0.85253229]]   # 2 by 2 matrix
X_aniso = np.dot(X, transformation)

# transformation here is to do matrix multiplication
# We have data X, which is a matrix [1500,2]
# We have a transformation matrix which is a matrix [2,2]
# x_aniso will be a matrix[1500,2]

# We group all the data into 3 clusters
y_pred_2 = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_aniso)

plt.scatter(X_aniso[:, 0], X_aniso[:, 1], c=y_pred_2)
plt.title("Anisotropicly Distributed Blobs")
# Out:
# Text(0.5, 1.0, 'Anisotropicly Distributed Blobs')

# %% [markdown]
# ### We can still see the three clusters in the transformed data.
# ### However, K-means does NOT work well for NON-Globular shapes. Thus the clustering results look bad.

# %%
X.shape
# Out:
# (1500, 2)

# %%
X_aniso.shape
# Out:
# (1500, 2)

# %%
print (X_aniso[0])
# Out:
# [-3.42469421  3.85671453]

# %%
print (X_aniso[1])
# Out:
# [-3.67055002  4.01922664]

# %%
# help (np.dot)

# %%
############################
# Print Cluster Centers    #
############################
y_pred_2_center = KMeans(n_clusters=3, random_state=random_state).fit(X_aniso)

label=y_pred_2_center.labels_
centroids = y_pred_2_center.cluster_centers_

u_labels = np.unique(label)
 
for i in u_labels:
    plt.scatter(X_aniso[label == i , 0] , X_aniso[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'k')
plt.legend()
plt.title("Anisotropicly Distributed Blobs with Centers")
plt.show()

# %% [markdown]
# ### 3.3 Figure 3: Different variance

# %%
# Generate New 1500 (n_samples) Data, each cluster with different std (standard deviation)
# There is one cluster with big variance (std): 10 (yellow one)
# The remaining two clusters have small variances (std): 0.01 and 0.05
X_varied, y_varied = make_blobs(n_samples=n_samples,
                                cluster_std=[0.01, 0.05, 10],
                                random_state=random_state)
# X_varied stores data
# y_varied stores labels: 0, 1, 2. However, We do not use labels in this clusterng process 
# (we can evluate the accuracy if we need to do so)

# cluster_std: float or sequence of floats, optional (default=1.0)
# The standard deviation of the clusters.

# Different clusters have different variance. 
# Specificially, cluster 2 has largest variance

y_pred_3 = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_varied)
plt.scatter(X_varied[:, 0], X_varied[:, 1], c=y_pred_3)
plt.title("Unequal Variance")
# It seems yellow color cluster has largest gradient
# Out:
# Text(0.5, 1.0, 'Unequal Variance')

# %%
X_varied.shape
# Out:
# (1500, 2)

# %%
############################
# Print Cluster Centers    #
############################
y_pred_3_center = KMeans(n_clusters=3, random_state=random_state).fit(X_varied)
label=y_pred_3_center.labels_
centroids = y_pred_3_center.cluster_centers_

u_labels = np.unique(label)
 
for i in u_labels:
    plt.scatter(X_varied[label == i , 0] , X_varied[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'k')
plt.legend()
plt.title("Unequal Variance with Centers")
plt.show()

# %% [markdown]
# ### 3.4 Figure 4: Unevenly sized blobs

# %%
# Generate New Data again - this time unevenly sized blob
X_filtered = np.vstack((X[y == 0][:1000], X[y == 1][:200], X[y == 2][:20]))

# Cluster 1 has 1000 points, Cluster 2 has 200 points, cluster 3 has 20 points

# Performing KMeans clustering
y_pred_4 = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_filtered)

plt.scatter(X_filtered[:, 0], X_filtered[:, 1], c=y_pred_4)
plt.title("Unevenly Sized Blobs")
# Out:
# Text(0.5, 1.0, 'Unevenly Sized Blobs')

# %%
############################
# Print Cluster Centers    #
############################
y_pred_4_center = KMeans(n_clusters=3, random_state=random_state).fit(X_filtered)
label=y_pred_4_center.labels_
centroids =y_pred_4_center.cluster_centers_

u_labels = np.unique(label)
 
for i in u_labels:
    plt.scatter(X_filtered[label == i , 0] , X_filtered[label == i , 1] , label = i)
plt.scatter(centroids[:,0] , centroids[:,1] , s = 80, color = 'k')
plt.legend()
plt.title("Unevenly Sized Blobs with Centers")
plt.show()

# %%
# help (plt.subplot)

# %% [markdown]
# ### subplot(nrows, ncols, plot_number)
#
# > Where *nrows* and *ncols* are used to notionally split the figure into ``nrows * ncols`` sub-axes,
#
# > *plot_number* is used to identify
# the particular subplot that this function is to create within the notional
# grid. *plot_number* starts at 1, increments across rows first and has a
# maximum of ``nrows * ncols``. It basically finishes the 1st row and then continues with 2rd row, ....
#
# #### In the case when *nrows*, *ncols* and *plot_number* are all less than 10, a convenience exists, such that the a 3 digit number (e.g. 211) can be given instead, where the hundreds represent *nrows*, the tens represent *ncols* and the units represent *plot_number*. For instance
#
#       subplot(221)
#
#
#
# ### produces a subaxes in a figure which represents the top left plot (i.e. the first) in a 2 row by 2 column notional grid (no grid actually exists, but conceptually this is how the returned subplot has been positioned).
#
#
# Grid|Col1|Col2
# -|-|-
# Row1|221|222
# Row2|223|224

# %%
# set the spacing between subplots
# We can use the plt.subplots_adjust() method to change the space between Matplotlib subplots. 
#The parameters wspace and hspace specify the space reserved between Matplotlib subplots. 
#They are the fractions of axis width and height, respectively. And the parameters left, right, top and bottom parameters 
#specify four sides of the subplots’ positions. They are the fractions of the width and height of the figure.
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.subplot(221)
# Grid with 2 Rows, 2 Column, we will draw the results in the first figure
plt.scatter(X[:, 0], X[:, 1], c=y_pred_1)   # All rows and two columns (we draw 1500 2D data)
plt.title("Incorrect Number of Blobs")
plt.subplot(222)
# Grid with 2 Rows, 2 Column, the second figure
plt.scatter(X_aniso[:, 0], X_aniso[:, 1], c=y_pred_2)
plt.title("Anisotropicly Distributed Blobs")

plt.subplot(223)
# Grid with 2 Rows, 2 Column, the third figure
plt.scatter(X_varied[:, 0], X_varied[:, 1], c=y_pred_3)
plt.title("Unequal Variance")

plt.subplot(224)
# Grid with 2 Rows, 2 Column, the fourth figure
plt.scatter(X_filtered[:, 0], X_filtered[:, 1], c=y_pred_4)
plt.title("Unevenly Sized Blobs")

#plt.show()
# Out:
# Text(0.5, 1.0, 'Unevenly Sized Blobs')

# %%
plt.figure(figsize=(15, 15))  # width=15, height=15 in inches

plt.subplot(221)
# Grid with 2 Rows, 2 Column, we will draw the results in the first figure
plt.scatter(X[:, 0], X[:, 1], c=y_pred_1)   # All rows and two columns (we draw 1500 2D data)
plt.title("Incorrect Number of Blobs")

plt.subplot(222)
# Grid with 2 Rows, 2 Column, the second figure
plt.scatter(X_aniso[:, 0], X_aniso[:, 1], c=y_pred_2)
plt.title("Anisotropicly Distributed Blobs")

plt.subplot(223)
# Grid with 2 Rows, 2 Column, the third figure
plt.scatter(X_varied[:, 0], X_varied[:, 1], c=y_pred_3)
plt.title("Unequal Variance")

plt.subplot(224)
# Grid with 2 Rows, 2 Column, the fourth figure
plt.scatter(X_filtered[:, 0], X_filtered[:, 1], c=y_pred_4)
plt.title("Unevenly Sized Blobs")

#plt.show()
# Out:
# Text(0.5, 1.0, 'Unevenly Sized Blobs')
